# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import matplotlib.pyplot as plt
import seaborn as sns

# 1. 데이터 로드
print("=" * 80)
print("데이터 로드")
print("=" * 80)

df = pd.read_csv('ethereum_preprocess.csv')
df['date'] = pd.to_datetime(df['date'])

print(f"Shape: {df.shape}")
print(f"기간: {df['date'].min()} ~ {df['date'].max()}")
# Out:
# ...
# 데이터 로드
# ...
# Shape: (1752, 332)
# 기간: 2020-12-19 00:00:00 ~ 2025-10-05 00:00:00

# %%
# 2. Feature/Target 분리
target_col = 'next_log_return'  # 또는 'next_close', 'next_direction'
exclude_cols = ['date', 'next_log_return', 'next_close', 'next_direction']
feature_cols = [col for col in df.columns if col not in exclude_cols]

print(f"Features: {len(feature_cols)}개")
print(f"Target: {target_col}")
# Out:
# Features: 328개
# Target: next_log_return

# %%
# 컬럼 Index 객체를 일반 파이썬 리스트로 변환
#column_list = df.columns.tolist()

# 리스트 출력 (보통 리스트는 생략 없이 모두 출력됩니다.)
#print(column_list)
df.columns
# Out:
# Index(['date', 'sentiment_mean', 'sentiment_std', 'news_count',
#        'positive_ratio', 'negative_ratio', 'extreme_positive_count',
#        'extreme_negative_count', 'sentiment_sum', 'sentiment_polarity',
#        ...
#        'avax_volatility_30d', 'avax_volume_change', 'avax_volume_ratio_20d',
#        'dot_return', 'dot_volatility_30d', 'dot_volume_change',
#        'dot_volume_ratio_20d', 'eth_btc_volume_corr_30d',
#        'eth_btc_volume_ratio', 'eth_btc_volume_ratio_ma30'],
#       dtype='object', length=332)
